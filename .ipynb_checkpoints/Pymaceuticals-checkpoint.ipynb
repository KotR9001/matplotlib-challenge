# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
from scipy.stats import sem
import numpy as np

# Study data files
mouse_metadata = "Mouse_metadata.csv"
study_results = "Study_results.csv"

# Read the mouse data and the study results
mouse_metadata = pd.read_csv(mouse_metadata)
study_results = pd.read_csv(study_results)

# Combine the data into a single dataset
mouse_study_df = pd.merge(mouse_metadata, study_results, on="Mouse ID")
mouse_study_df
# Out:
#      Mouse ID Drug Regimen   Sex  Age_months  Weight (g)  Timepoint  \
# 0        k403     Ramicane  Male          21          16          0
# 1        k403     Ramicane  Male          21          16          5
# 2        k403     Ramicane  Male          21          16         10
# 3        k403     Ramicane  Male          21          16         15
# 4        k403     Ramicane  Male          21          16         20
# ...       ...          ...   ...         ...         ...        ...
# 1888     z969     Naftisol  Male           9          30         25
# 1889     z969     Naftisol  Male           9          30         30
# 1890     z969     Naftisol  Male           9          30         35
# 1891     z969     Naftisol  Male           9          30         40
# 1892     z969     Naftisol  Male           9          30         45
#
#       Tumor Volume (mm3)  Metastatic Sites
# 0              45.000000                 0
# 1              38.825898                 0
# ...

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume for each regimen

#Group By Drug Regimen
drug_column = mouse_study_df.groupby('Drug Regimen')

#Obtain the List of Drug Regimens
drug_sort = mouse_study_df['Drug Regimen'].sort_values()
drug_list = drug_sort.unique()

#Create the Mean List
tumor_vol_mean_list = drug_column['Tumor Volume (mm3)'].mean().unique()

#Create the Median List
tumor_vol_median_list = drug_column['Tumor Volume (mm3)'].median().unique()

#Create the Variance List
tumor_vol_variance_list = drug_column['Tumor Volume (mm3)'].var().unique()
    
#Create the St. Dev. List
tumor_vol_std_list = drug_column['Tumor Volume (mm3)'].std().unique()
    
#Fill the SEM List
tumor_vol_sem_list = drug_column['Tumor Volume (mm3)'].sem().unique()


#Create the DataFrame
summary_df = pd.DataFrame({'Mean Volume':tumor_vol_mean_list, 'Median Volume':tumor_vol_median_list, 'Variance in Volume':tumor_vol_variance_list, 'St. Dev. of Volume':tumor_vol_std_list, 'SEM of Volume':tumor_vol_sem_list}, index = drug_list)
#Map to Round the Decimal Points
#summary_df['Mean Volume'] = summary_df['Mean Volume'].map('{:.2f}')
#summary_df['Median Volume'] = summary_df['Median Volume'].map('{:.2f}')
#summary_df['Variance in Volume'] = summary_df['Variance in Volume'].map('{:.2f}')
#summary_df['St. Dev. of Volume'] = summary_df['St. Dev. of Volume'].map('{:.2f}')
#summary_df['SEM of Volume'] = summary_df['SEM of Volume'].map('{:.2f}')
#Print the DataFrame
summary_df
# Out:
#            Mean Volume  Median Volume  Variance in Volume  St. Dev. of Volume  \
# Capomulin    40.675741      41.557809           24.947764            4.994774
# Ceftamin     52.591172      51.776157           39.290177            6.268188
# Infubinol    52.884795      51.820584           43.128684            6.567243
# Ketapril     55.235638      53.698743           68.553577            8.279709
# Naftisol     54.331565      52.509285           66.173479            8.134708
# Placebo      54.033581      52.288934           61.168083            7.821003
# Propriva     52.322552      50.854632           42.351070            6.507770
# Ramicane     40.216745      40.673236           23.486704            4.846308
# Stelasyn     54.233149      52.431737           59.450562            7.710419
# Zoniferol    53.236507      51.818479           48.533355            6.966589
#
#            SEM of Volume
# Capomulin       0.329346
# Ceftamin        0.469821
# Infubinol       0.492236
# ...

# %%
# Generate a bar plot showing number of data points for each treatment regimen using pandas

#Obtain the List of Treatment Data Points
treatment_df = mouse_study_df.groupby('Drug Regimen')
treatment_count = treatment_df['Timepoint'].count()

#Create DataFrame for Columns
drug_df = pd.DataFrame({'Drug Regimen':drug_list, 'Number of Treatments':treatment_count})

#Create the Bar Chart
bar = drug_df.plot(kind = "bar", figsize=(6,4), width=0.75)
#Create the Title and Axis Labels
#Label Syntax found on https://stackoverflow.com/questions/21487329/add-x-and-y-labels-to-a-pandas-plot
bar.set_title("Drug Regimen Frequency")
bar.set_xlabel("Drug Regimen")
bar.set_ylabel("Number of Treatments")
#Show the Bar Chart
bar

# %%
# Generate a bar plot showing number of data points for each treatment regimen using pyplot

#Determine Criteria for the Bar Chart
#Syntax found on MatPlotLib Day 2 Plot_Drills
#Set the Length of the x-Axis
x_axis = np.arange(0, len(drug_list))
#Set the Tick Locations
tick_locations = []
for x in x_axis:
    tick_locations.append(x)

#Create the Title and Axis Labels
title = plt.title('Drug Regimen Frequency')
xlabel = plt.xlabel('Drug Regimen')
ylabel = plt.ylabel('Number of Treatments')

#Set the x and y Axis Limits
plt.xlim(-0.75, len(drug_list)-.25)
plt.ylim(0, max(treatment_count) + 5)

#Create the Bar Chart
bar1 = plt.bar(drug_df['Drug Regimen'], drug_df['Number of Treatments'])
#Create the Ticks
plt.xticks(tick_locations, drug_list, rotation = 90)
#Show the Bar Chart
bar1
# Out:
# <BarContainer object of 10 artists>

# %%
# Generate a pie plot showing the distribution of female versus male mice using pandas

#Create a List of Sexes
sex_sort = mouse_metadata['Sex'].sort_values()
sex_list = sex_sort.unique().astype(str)

#Create a Count of Sexes
sex_type_df = mouse_metadata.groupby('Sex')
sex_count = sex_type_df['Sex'].count()

#Create a DataFrame with Sex Data
sex_df = pd.DataFrame({'Sex':sex_list, 'Sex Count':sex_count})
sex_df

#Create a Pie Chart of Sex Distribution
#Syntax and Arguments found on MatPlotLib Day 1 Activity 9: Pie Charts
#Used Single Column Array Instead of Whole DataFrame in Order to Produce Plot
#Credit to Don Caswell
pie = sex_count.plot.pie(labels = sex_list, title = ('Distribution of Female vs Male Mice'), colors = ["blue", "red"], explode = [0.1,0], autopct="%1.1f%%", shadow=True, startangle=90)
pie.set_ylabel('Sex Count')
#Set the Size of the Layout
plt.tight_layout()
#Ensure the Pie Chart is Perfectly Rounded
plt.axis("equal")
#Show the Plot
plt.show()
sex_count
# Out:
# Sex
# Female    124
# Male      125
# Name: Sex, dtype: int64

# %%
# Generate a pie plot showing the distribution of female versus male mice using pyplot

#Create the Title and Axis Labels
title1 = plt.title('Distribution of Female vs Male Mice')
ylabel1 = plt.ylabel('Sex Count')

#Create the Pie Chart
#Syntax and Arguments found on MatPlotLib Day 1 Activity 9: Pie Charts
#Used Single Column Array Instead of Whole DataFrame in Order to Produce Plot
#Credit to Don Caswell
pie1 = plt.pie(sex_count, labels = sex_list, colors = ["blue", "red"], explode = [0.1,0], autopct="%1.1f%%", shadow=True, startangle=90)
pie.set_ylabel('Sex Count')
#Set the Size of the Layout
plt.tight_layout()
#Ensure the Pie Chart is Perfectly Rounded
plt.axis("equal")
#Show the Plot
plt.show()

# %%
# Calculate the final tumor volume of each mouse across four of the most promising treatment regimens. Calculate the IQR and quantitatively determine if there are any potential outliers.

#Sort the Merged DataFrame by 'Drug Regimen'
drug_sort1 = mouse_study_df.sort_values(['Drug Regimen'])

#Return DataFrame with Capomulin Trial Data
final_capomulin_reg = drug_sort1.loc[drug_sort1['Drug Regimen'] == 'Capomulin']
#Sort Values by 'Mouse ID'
final_capomulin_reg_mouse_sort = final_capomulin_reg.sort_values(['Mouse ID'])
#GroupBy 'Mouse ID'
final_capomulin_reg_mouse = final_capomulin_reg_mouse_sort.groupby(['Mouse ID'])
#Return the Tumor Volume Data for Each Mouse->Trial
final_capomulin_reg_mouse_vol = final_capomulin_reg_mouse['Tumor Volume (mm3)'].unique()

#Create List for Final Tumor Volumes onto Capomulin List
capomulin_list = []
#Append Final Volumes onto Capomulin List
for vol in final_capomulin_reg_mouse_vol[:]:
    capomulin_list.append(vol[0])
#Put List in Column
capomulin_df = pd.DataFrame({'Final Volume':capomulin_list})
#Sort Values
capomulin_df = capomulin_df.sort_values('Final Volume', ascending = True)

#Return DataFrame with Ramicane Trial Data
final_ramicane_reg = drug_sort1.loc[drug_sort1['Drug Regimen'] == 'Ramicane']
#Sort Values by 'Mouse ID'
final_ramicane_reg_mouse_sort = final_ramicane_reg.sort_values(['Mouse ID'])
#GroupBy 'Mouse ID'
final_ramicane_reg_mouse = final_ramicane_reg_mouse_sort.groupby(['Mouse ID'])
#Return the Tumor Volume Data for Each Mouse->Trial
final_ramicane_reg_mouse_vol = final_ramicane_reg_mouse['Tumor Volume (mm3)'].unique()

#Create List for Final Tumor Volumes onto Ramicane List
ramicane_list = []
#Append Final Volumes onto Ramicane List
for vol in final_ramicane_reg_mouse_vol[:]:
    ramicane_list.append(vol[0])
#Put List in Column
ramicane_df = pd.DataFrame({'Final Volume':ramicane_list})
#Sort Values
ramicane_df = ramicane_df.sort_values('Final Volume', ascending = True)
    
#Return DataFrame with Infubinol Trial Data
final_infubinol_reg = drug_sort1.loc[drug_sort1['Drug Regimen'] == 'Infubinol']
#Sort Values by 'Mouse ID'
final_infubinol_reg_mouse_sort = final_infubinol_reg.sort_values(['Mouse ID'])
#GroupBy 'Mouse ID'
final_infubinol_reg_mouse = final_infubinol_reg_mouse_sort.groupby(['Mouse ID'])
#Return the Tumor Volume Data for Each Mouse->Trial
final_infubinol_reg_mouse_vol = final_infubinol_reg_mouse['Tumor Volume (mm3)'].unique()

#Create List for Final Tumor Volumes onto Infubinol List
infubinol_list = []
#Append Final Volumes onto Infubinol List
for vol in final_infubinol_reg_mouse_vol[:]:
    infubinol_list.append(vol[0])
#Put List in Column
infubinol_df = pd.DataFrame({'Final Volume':infubinol_list})
#Sort Values
infubinol_df = infubinol_df.sort_values('Final Volume', ascending = True)

#Return DataFrame with Ceftamin Trial Data
final_ceftamin_reg = drug_sort1.loc[drug_sort1['Drug Regimen'] == 'Ceftamin']
#Sort Values by 'Mouse ID'
final_ceftamin_reg_mouse_sort = final_ceftamin_reg.sort_values(['Mouse ID'])
#GroupBy 'Mouse ID'
final_ceftamin_reg_mouse = final_ceftamin_reg_mouse_sort.groupby(['Mouse ID'])
#Return the Tumor Volume Data for Each Mouse->Trial
final_ceftamin_reg_mouse_vol = final_ceftamin_reg_mouse['Tumor Volume (mm3)'].unique()

#Create List for Final Tumor Volumes onto Ceftamin List
ceftamin_list = []
#Append Final Volumes onto Ceftamin List
for vol in final_ceftamin_reg_mouse_vol[:]:
    ceftamin_list.append(vol[0])
#Put List in Column
ceftamin_df = pd.DataFrame({'Final Volume':ceftamin_list})
#Sort Values
ceftamin_df = ceftamin_df.sort_values('Final Volume', ascending = True)

#Calculate the Quartiles
#Capomulin
capomulin_quartiles = capomulin_df['Final Volume'].quantile([0.25,0.5,0.75])
capomulin_lower = capomulin_quartiles[0.25]
capomulin_upper = capomulin_quartiles[0.75]
capomulin_iqr = capomulin_upper - capomulin_lower
capomulin_iqr
capomulin_lbound = capomulin_lower - 1.5 * capomulin_iqr
capomulin_ubound = capomulin_upper + 1.5 * capomulin_iqr

#Ramicane
ramicane_quartiles = ramicane_df['Final Volume'].quantile([0.25,0.5,0.75])
ramicane_lower = ramicane_quartiles[0.25]
ramicane_upper = ramicane_quartiles[0.75]
ramicane_iqr = ramicane_upper - ramicane_lower
ramicane_iqr
ramicane_lbound = ramicane_lower - 1.5 * ramicane_iqr
ramicane_ubound = ramicane_upper + 1.5 * ramicane_iqr

#Infubinol
infubinol_quartiles = infubinol_df['Final Volume'].quantile([0.25,0.5,0.75])
infubinol_lower = infubinol_quartiles[0.25]
infubinol_upper = infubinol_quartiles[0.75]
infubinol_iqr = infubinol_upper - infubinol_lower
infubinol_iqr
infubinol_lbound = infubinol_lower - 1.5 * infubinol_iqr
infubinol_ubound = infubinol_upper + 1.5 * infubinol_iqr

#Ceftamin
ceftamin_quartiles = ceftamin_df['Final Volume'].quantile([0.25,0.5,0.75])
ceftamin_lower = ceftamin_quartiles[0.25]
ceftamin_upper = ceftamin_quartiles[0.75]
ceftamin_iqr = ceftamin_upper - ceftamin_lower
ceftamin_iqr
ceftamin_lbound = ceftamin_lower - 1.5 * ceftamin_iqr
ceftamin_ubound = ceftamin_upper + 1.5 * ceftamin_iqr

#Create a Quartile DataFrame
quartile_df = pd.DataFrame({'Lower Quartile':[capomulin_lower, ramicane_lower, infubinol_lower, ceftamin_lower],
                           'Upper Quartile':[capomulin_upper, ramicane_upper, infubinol_upper, ceftamin_upper],
                           'IQR':[capomulin_iqr, ramicane_iqr, infubinol_iqr, ceftamin_iqr],
                           'Lower Bound':[capomulin_lbound, ramicane_lbound, infubinol_lbound, ceftamin_lbound],
                           'Upper Bound':[capomulin_ubound, ramicane_ubound, infubinol_ubound, ceftamin_ubound]},
                           index=['Capomulin', 'Ramicane', 'Infubinol', 'Ceftamin'])
print(f"The final volume values for Capomulin trials are {capomulin_df}.") 
print(f"The final volume values for Ramicane trials are {ramicane_df}.")
print(f"The final volume values for Infubinol trials are {infubinol_df}.")
print(f"The final volume values for Ceftamin trials are {ceftamin_df}.")
quartile_df

#Potential Outliers
#Capomulin: N/A
#Ramicane: N/A
#Infubinol: [72.226731]
#Ceftamin: N/A
# Out:
# The final volume values for Capomulin trials are     Final Volume
# 16     25.472143
# 24     31.896238
# 23     32.915292
# 12     32.947615
# 11     33.118756
# 19     35.503616
# 2      35.624403
# 22     36.041047
# 8      38.753265
# 1      38.939633
# 20     40.658124
# 3      42.368692
# 15     43.225671
# 17     43.571703
# 0      43.784893
# 5      43.967895
# 4      44.221480
# 7      44.585090
# 10     45.000000
# 9      45.000000
# 21     45.000000
# 6      45.000000
# 13     45.000000
# 14     45.781746
# 18     45.895647.
# The final volume values for Ramicane trials are     Final Volume
# 20     30.276232
# 14     35.114575
# 12     35.115590
# 9      35.557933
# 17     36.561652
# 18     37.225650
# 10     39.005554
# 8      40.170558
# 15     40.375138
# 21     40.667713
# 11     42.168341
# 1      42.291394
# 19     43.527261
# 4      44.454378
# 22     45.000000
# 24     45.000000
# 6      45.000000
# 3      45.000000
# 2      45.000000
# 13     45.000000
# ...

# %%
# Generate a box plot of the final tumor volume of each mouse across four regimens of interest

# %%
# Generate a line plot of time point versus tumor volume for a mouse treated with Capomulin

# %%
# Generate a scatter plot of mouse weight versus average tumor volume for the Capomulin regimen

# %%
# Calculate the correlation coefficient and linear regression model for mouse weight and average tumor volume for the Capomulin regimen
